# %%
import random

import pandas as pd
import numpy as np
import networkx as nx

from tqdm.notebook import tqdm
from argparse import ArgumentParser
from collections import namedtuple
from ast import literal_eval

import main  # to use functions accessing data

# Columns of CONLL file
CONLL_COLS = ['index',
              'sentence',
              'lemma_sentence',
              'upos_sentence',
              'xpos_sentence',
              'morph',
              'head_indices',
              'governance_relations',
              'secondary_relations',
              'extra_info']
ObservationClass = namedtuple("Observation", CONLL_COLS)

# %%
OBSERVATIONS = main.load_conll_dataset("ptb3-wsj-data/ptb3-wsj-dev.conllx",
                                       ObservationClass)
EDGES_DF = pd.read_csv("results-azure/bert-large-cased_pad60_2020-04-09-13-57/scores_bert-large-cased_pad60_2020-04-09-13-57.csv")

# %%
EXCLUDED_PUNCTUATION = ["", "'", "''", ",", ".", ";", "!", "?", ":", "``", "-LRB-", "-RRB-"]

def is_edge_to_ignore(edge, observation):
    is_d_punct = bool(observation.sentence[edge[1]-1] in EXCLUDED_PUNCTUATION)
    is_h_root = bool(edge[0] == 0)
    return is_d_punct or is_h_root

def score_observation(predicted_edges, observation, convert_from_0index=False):
    # get gold edges (1-indexed)
    gold_edges_list = list(zip(list(map(int, observation.head_indices)),
                               list(map(int, observation.index)),
                               observation.governance_relations))
    gold_edge_to_label = {(e[0], e[1]): e[2] for e in gold_edges_list
                          if not is_edge_to_ignore(e, observation)}
    # just the unlabeled edges
    gold_edges_set = {tuple(sorted(e)) for e in gold_edge_to_label.keys()}

    # note converting to 1-indexing
    k = 1 if convert_from_0index else 0
    predicted_edges_set = {tuple(sorted((x[0]+k, x[1]+k))) for x in predicted_edges}

    correct_edges = list(gold_edges_set.intersection(predicted_edges_set))
    incorrect_edges = list(predicted_edges_set.difference(gold_edges_set))
    num_correct = len(correct_edges)
    num_total = len(gold_edges_set)
    uuas = num_correct/float(num_total) if num_total != 0 else np.NaN
    return uuas

# %%
def Lk(ls):
    """Given a length sequence ls,
    Returns 
        L: the length sequence (sorted)
        k: a list of the counts of each length in L"""
    L = sorted(ls)
    k = [L.count(n) for n in range(L[-1]+1)]
    return L,k

def lengthmatch(observation):
    '''get gold edge set and length sequence'''
    # get gold edges (1-indexed)
    gold_edges_list = list(zip(list(map(int, observation.head_indices)),
                               list(map(int, observation.index)),
                               observation.governance_relations))
    gold_edge_to_label = {(e[0], e[1]): e[2] for e in gold_edges_list
                          if not is_edge_to_ignore(e, observation)}
    # just the unlabeled edges
    gold_edges_set = {tuple(sorted(e)) for e in gold_edge_to_label.keys()}
    lens = [e[1]-e[0] for e in gold_edges_set]
    return lens, gold_edges_set

# %%
# obs = OBSERVATIONS[13]

# lens, ges = lengthmatch(obs)
# print(lens)
# print(ges)

# G=nx.Graph()
# G.add_edges_from(ges)
# # G.remove_edges_from(ges)
# print(sorted(G.edges()))
# bool((2,1) in G.edges())
# print("Is a tree?",nx.is_forest(G))
# score_observation(G.edges(),obs)

# %%
def generate_lengthmatch(observation, make_tree=True, iterations=100):
    '''
    generate length-matched baseline of observation
    after algorithm described in
    https://cs.stackexchange.com/questions/116193
    '''
    lens, ges = lengthmatch(observation)
    print(f"len {len(observation[0])}", end=". ")
    # initialize a graph with the right number of nodes
    for iteration in range(iterations):

        T=nx.Graph()
        T.add_edges_from(ges)
        T.remove_edges_from(ges)
        L,k = Lk(lens)
        
        # for each edge length
        for l in set(L):
            V=T.nodes()
            E=T.edges()

            # generate set P of possible new edges of len l
            eplus = set(tuple(sorted((u,u+l))) for u in V if u+l in V and (u,u+l) not in E)
            eminus= set(tuple(sorted((u,u-l))) for u in V if u-l in V and (u,u-l) not in E)
            P = eplus.union(eminus)
            if len(P)==0:
                raise ValueError("ERROR: no possible edges")
            # sampling k[l] edges of length l from P
            additional_edges = random.sample(P,k[l])
            T.add_edges_from(additional_edges)

            if make_tree and not nx.is_forest(T):
                break
                
        if (make_tree and nx.is_tree(T)) or not make_tree:
            if make_tree: 
                print(f"success after {iteration} iterations")
            return score_observation(T.edges(),observation)
    print(f"FAILED (reached max iterations {iterations})")
    return np.NaN
        
# generate_lengthmatch(OBSERVATIONS[65],make_tree=True)

# %%
scores=[]
countobs=0
for i, obs in enumerate(tqdm(OBSERVATIONS)):
    print(str(i).ljust(4),end="")
    if 35 < len(obs[0]):
        countobs +=1
        scores.append(generate_lengthmatch(obs, iterations=15000))
    else:
        print(f"len {len(obs[0])}","(too short/long)")
failurecount = scores.count(np.NaN)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=1700.0), HTML(value='')))
# 0   len 37. FAILED (reached max iterations 15000)
# 1   len 45. FAILED (reached max iterations 15000)
# 2   len 20 (too long)
# 3   len 37. success after 3994 iterations
# 4   len 23 (too long)
# 5   len 22 (too long)
# 6   len 17 (too long)
# 7   len 28 (too long)
# 8   len 34 (too long)
# 9   len 23 (too long)
# 10  len 30 (too long)
# 11  len 29 (too long)
# 12  len 23 (too long)
# 13  len 13 (too long)
# 14  len 20 (too long)
# 15  len 42. FAILED (reached max iterations 15000)
# 16  len 44. FAILED (reached max iterations 15000)
# 17  len 27 (too long)
# 18  len 26 (too long)
# 19  len 15 (too long)
# 20  len 9 (too long)
# 21  len 42. FAILED (reached max iterations 15000)
# 22  len 22 (too long)
# 23  len 17 (too long)
# 24  len 10 (too long)
# 25  len 22 (too long)
# 26  len 17 (too long)
# 27  len 14 (too long)
# 28  len 21 (too long)
# 29  len 18 (too long)
# 30  len 26 (too long)
# 31  len 8 (too long)
# 32  len 17 (too long)
# 33  len 27 (too long)
# 34  len 21 (too long)
# 35  len 32 (too long)
# 36  len 21 (too long)
# 37  len 9 (too long)
# 38  len 12 (too long)
# 39  len 11 (too long)
# 40  len 24 (too long)
# 41  len 40. FAILED (reached max iterations 15000)
# 42  len 13 (too long)
# 43  len 14 (too long)
# 44  len 40. FAILED (reached max iterations 15000)
# 45  len 20 (too long)
# 46  len 32 (too long)
# 47  len 29 (too long)
# 48  len 19 (too long)
# 49  len 13 (too long)
# 50  len 11 (too long)
# 51  len 21 (too long)
# 52  len 41. FAILED (reached max iterations 15000)
# 53  len 18 (too long)
# 54  len 11 (too long)
# 55  len 23 (too long)
# 56  len 23 (too long)
# 57  len 33 (too long)
# 58  len 28 (too long)
# 59  len 22 (too long)
# 60  len 14 (too long)
# 61  len 27 (too long)
# 62  len 24 (too long)
# 63  len 15 (too long)
# 64  len 24 (too long)
# 65  len 17 (too long)
# 66  len 4 (too long)
# 67  len 3 (too long)
# 68  len 31 (too long)
# 69  len 5 (too long)
# 70  len 20 (too long)
# 71  len 18 (too long)
# 72  len 31 (too long)
# 73  len 12 (too long)
# 74  len 3 (too long)
# 75  len 31 (too long)
# 76  len 27 (too long)
# 77  len 19 (too long)
# 78  len 13 (too long)
# 79  len 57. FAILED (reached max iterations 15000)
# 80  len 36. success after 865 iterations
# 81  len 54. FAILED (reached max iterations 15000)
# 82  len 19 (too long)
# 83  len 33 (too long)
# 84  len 32 (too long)
# 85  len 27 (too long)
# 86  len 22 (too long)
# 87  len 31 (too long)
# 88  len 37. FAILED (reached max iterations 15000)
# 89  len 36. FAILED (reached max iterations 15000)
# 90  len 23 (too long)
# 91  len 53. FAILED (reached max iterations 15000)
# 92  len 31 (too long)
# 93  len 23 (too long)
# 94  len 29 (too long)
# 95  len 28 (too long)
# 96  len 30 (too long)
# 97  len 10 (too long)
# 98  len 52. FAILED (reached max iterations 15000)
# 99  len 42. FAILED (reached max iterations 15000)
# 100 len 17 (too long)
# 101 len 15 (too long)
# 102 len 5 (too long)
# 103 len 33 (too long)
# 104 len 11 (too long)
# 105 len 36. success after 7691 iterations
# 106 len 54. FAILED (reached max iterations 15000)
# 107 len 15 (too long)
# 108 len 33 (too long)
# 109 len 32 (too long)
# 110 len 40. FAILED (reached max iterations 15000)
# 111 len 8 (too long)
# 112 len 22 (too long)
# 113 len 44. FAILED (reached max iterations 15000)
# 114 len 18 (too long)
# 115 len 22 (too long)
# 116 len 22 (too long)
# 117 len 13 (too long)
# 118 len 26 (too long)
# 119 len 21 (too long)
# 120 len 26 (too long)
# 121 len 19 (too long)
# 122 len 19 (too long)
# 123 len 5 (too long)
# 124 len 24 (too long)
# 125 len 21 (too long)
# 126 len 27 (too long)
# 127 len 11 (too long)
# 128 len 13 (too long)
# 129 len 44. FAILED (reached max iterations 15000)
# 130 len 20 (too long)
# 131 len 20 (too long)
# 132 len 30 (too long)
# 133 len 58. FAILED (reached max iterations 15000)
# 134 len 21 (too long)
# 135 len 27 (too long)
# 136 len 21 (too long)
# 137 len 13 (too long)
# 138 len 25 (too long)
# 139 len 34 (too long)
# 140 len 13 (too long)
# 141 len 20 (too long)
# 142 len 39. FAILED (reached max iterations 15000)
# 143 len 30 (too long)
# 144 len 35 (too long)
# 145 len 25 (too long)
# 146 len 9 (too long)
# 147 len 8 (too long)
# 148 len 30 (too long)
# 149 len 30 (too long)
# 150 len 15 (too long)
# 151 len 16 (too long)
# 152 len 19 (too long)
# 153 len 20 (too long)
# 154 len 10 (too long)
# 155 len 20 (too long)
# 156 len 14 (too long)
# 157 len 19 (too long)
# 158 len 29 (too long)
# 159 len 19 (too long)
# 1002len 16 (too long)
# 1003len 12 (too long)
# 1004len 33 (too long)
# 1005len 39. FAILED (reached max iterations 15000)
# 1006len 25 (too long)
# 1007len 10 (too long)
# 1008len 1 (too long)
# 1009len 18 (too long)
# 1010len 29 (too long)
# 1011len 29 (too long)
# 1012len 41. FAILED (reached max iterations 15000)
# 1013len 8 (too long)
# 1014len 22 (too long)
# 1015len 30 (too long)
# 1016len 20 (too long)
# 1017len 26 (too long)
# 1018len 23 (too long)
# 1019len 10 (too long)
# 1020len 39. success after 6718 iterations
# 1021len 37. FAILED (reached max iterations 15000)
# 1022len 38. FAILED (reached max iterations 15000)
# 1023len 23 (too long)
# 1024len 20 (too long)
# 1025len 36. FAILED (reached max iterations 15000)
# 1026len 49. FAILED (reached max iterations 15000)
# 1027len 16 (too long)
# 1028len 18 (too long)
# 1029len 52. FAILED (reached max iterations 15000)
# 1030len 12 (too long)
# 1031len 13 (too long)
# 1032len 16 (too long)
# 1033len 33 (too long)
# 1034len 29 (too long)
# 1035len 9 (too long)
# 1036len 24 (too long)
# 1037len 44. FAILED (reached max iterations 15000)
# 1038len 13 (too long)
# 1039len 20 (too long)
# 1040len 33 (too long)
# 1041len 20 (too long)
# 1042len 24 (too long)
# 1043len 19 (too long)
# 1044len 19 (too long)
# 1045len 20 (too long)
# 1046len 45. FAILED (reached max iterations 15000)
# 1047len 12 (too long)
# 1048len 53. FAILED (reached max iterations 15000)
# 1049len 32 (too long)
# 1050len 37. FAILED (reached max iterations 15000)
# 1051len 20 (too long)
# 1052len 15 (too long)
# 1053len 21 (too long)
# 1054len 24 (too long)
# 1055len 41. FAILED (reached max iterations 15000)
# 1056len 32 (too long)
# 1057len 12 (too long)
# 1058len 17 (too long)
# 1059len 18 (too long)
# 1060len 19 (too long)
# 1061len 13 (too long)
# 1062len 35 (too long)
# 1063len 28 (too long)
# 1064len 32 (too long)
# 1065len 41. FAILED (reached max iterations 15000)
# 1066len 29 (too long)
# 1067len 25 (too long)
# 1068len 31 (too long)
# 1069len 24 (too long)
# 1070len 34 (too long)
# 1071len 31 (too long)
# 1072len 15 (too long)
# 1073len 24 (too long)
# 1074len 10 (too long)
# 1075len 23 (too long)
# 1076len 15 (too long)
# 1077len 15 (too long)
# 1078len 31 (too long)
# 1079len 28 (too long)
# 1080len 26 (too long)
# 1081len 21 (too long)
# 1082len 25 (too long)
# 1083len 16 (too long)
# 1084len 11 (too long)
# 1085len 27 (too long)
# 1086len 22 (too long)
# 1087len 6 (too long)
# 1088len 13 (too long)
# 1089len 10 (too long)
# 1090len 14 (too long)
# 1091len 17 (too long)
# 1092len 16 (too long)
# 1093len 9 (too long)
# 1094len 20 (too long)
# 1095len 21 (too long)
# 1096len 26 (too long)
# 1097len 28 (too long)
# 1098len 17 (too long)
# 1099len 34 (too long)
# 1100len 20 (too long)
# 1101len 42. FAILED (reached max iterations 15000)
# 1102len 23 (too long)
# 1103len 25 (too long)
# 1104len 22 (too long)
# 1105len 30 (too long)
# 1106len 35 (too long)
# 1107len 27 (too long)
# 1108len 30 (too long)
# 1109len 18 (too long)
# 1110len 5 (too long)
# 1111len 19 (too long)
# 1112len 31 (too long)
# 1113len 16 (too long)
# 1114len 27 (too long)
# 1115len 15 (too long)
# 1116len 28 (too long)
# 1117len 30 (too long)
# 1118len 31 (too long)
# 1119len 17 (too long)
# 1120len 18 (too long)
# 1121len 37. FAILED (reached max iterations 15000)
# 1122len 17 (too long)
# 1123len 9 (too long)
# 1124len 19 (too long)
# 1125len 27 (too long)
# 1126len 23 (too long)
# 1127len 15 (too long)
# 1128len 8 (too long)
# 1129len 17 (too long)
# 1130len 12 (too long)
# 1131len 24 (too long)
# 1132len 17 (too long)
# 1133len 12 (too long)
# 1134len 9 (too long)
# 1135len 19 (too long)
# 1136len 17 (too long)
# 1137len 24 (too long)
# 1138len 19 (too long)
# 1139len 7 (too long)
# 1140len 31 (too long)
# 1141len 34 (too long)
# 1142len 22 (too long)
# 1143len 16 (too long)
# 1144len 27 (too long)
# 1145len 26 (too long)
# 1146len 15 (too long)
# 1147len 12 (too long)
# 1148len 35 (too long)
# 1149len 22 (too long)
# 1150len 6 (too long)
# 1151len 41. FAILED (reached max iterations 15000)
# 1152len 15 (too long)
# 1153len 21 (too long)
# 1154len 38. success after 7039 iterations
# 1155len 14 (too long)
# 1156len 25 (too long)
# 1157len 23 (too long)
# 1158len 30 (too long)
# 1159len 6 (too long)
# 1160len 30 (too long)
# 1161len 15 (too long)
# 1162len 19 (too long)
# 1163len 26 (too long)
# 1164len 43. FAILED (reached max iterations 15000)
# 1165len 46. FAILED (reached max iterations 15000)
# 1166len 18 (too long)
# 1167len 24 (too long)
# 1168len 30 (too long)
# 1169len 25 (too long)
# 1170len 32 (too long)
# 1171len 39. FAILED (reached max iterations 15000)
# 1172len 17 (too long)
# 1173len 22 (too long)
# 1174len 35 (too long)
# 1175len 19 (too long)
# 1176len 35 (too long)
# 1177len 35 (too long)
# 1178len 31 (too long)
# 1179len 36. FAILED (reached max iterations 15000)
# 1180len 19 (too long)
# 1181len 19 (too long)
# 1182len 34 (too long)
# 1183len 16 (too long)
# 1184len 12 (too long)
# 1185len 40. success after 5244 iterations
# 1186len 45. FAILED (reached max iterations 15000)
# 1187len 48. FAILED (reached max iterations 15000)
# 1188len 26 (too long)
# 1189len 25 (too long)
# 1190len 41. FAILED (reached max iterations 15000)
# 1191len 25 (too long)
# 1192len 25 (too long)
# 1193len 9 (too long)
# 1194len 23 (too long)
# 1195len 16 (too long)
# 1196len 32 (too long)
# 1197len 16 (too long)
# 1198len 24 (too long)
# 1199len 23 (too long)
# 1200len 12 (too long)
# 1201len 21 (too long)
# 1202len 42. FAILED (reached max iterations 15000)
# 1203len 14 (too long)
# 1204len 37. FAILED (reached max iterations 15000)
# 1205len 7 (too long)
# 1206len 19 (too long)
# 1207len 23 (too long)
# 1208len 13 (too long)
# 1209len 29 (too long)
# 1210len 31 (too long)
# 1211len 25 (too long)
# 1212len 29 (too long)
# 1213len 21 (too long)
# 1214len 15 (too long)
# 1215len 11 (too long)
# 1216len 4 (too long)
# 1217len 17 (too long)
# 1218len 8 (too long)
# 1219len 22 (too long)
# 1220len 9 (too long)
# 1221len 20 (too long)
# 1222len 9 (too long)
# 1223len 22 (too long)
# 1224len 16 (too long)
# 1225len 19 (too long)
# 1226len 13 (too long)
# 1227len 26 (too long)
# 1228len 16 (too long)
# 1229len 24 (too long)
# 1230len 11 (too long)
# 1231len 17 (too long)
# 1232len 15 (too long)
# 1233len 13 (too long)
# 1234len 19 (too long)
# 1235len 28 (too long)
# 1236len 12 (too long)
# 1237len 19 (too long)
# 1238len 17 (too long)
# 1239len 15 (too long)
# 1240len 21 (too long)
# 1241len 7 (too long)
# 1242len 22 (too long)
# 1243len 2 (too long)
# 1244len 6 (too long)
# 1245len 20 (too long)
# 1246len 10 (too long)
# 1247len 18 (too long)
# 1248len 14 (too long)
# 1249len 6 (too long)
# 1250len 23 (too long)
# 1251len 7 (too long)
# 1252len 14 (too long)
# 1253len 25 (too long)
# 1254len 17 (too long)
# 1255len 10 (too long)
# 1256len 6 (too long)
# 1257len 15 (too long)
# 1258len 10 (too long)
# 1259len 11 (too long)
# 1260len 59. FAILED (reached max iterations 15000)
# 1261len 33 (too long)
# 1262len 29 (too long)
# 1263len 28 (too long)
# 1264len 7 (too long)
# 1265len 22 (too long)
# 1266len 33 (too long)
# 1267len 12 (too long)
# 1268len 64. FAILED (reached max iterations 15000)
# 1269len 32 (too long)
# 1270len 21 (too long)
# 1271len 24 (too long)
# 1272len 15 (too long)
# 1273len 49. FAILED (reached max iterations 15000)
# 1274len 22 (too long)
# 1275len 20 (too long)
# 1276len 6 (too long)
# 1277len 45. success after 9295 iterations
# 1278len 6 (too long)
# 1279len 9 (too long)
# 1280len 20 (too long)
# 1281len 22 (too long)
# 1282len 27 (too long)
# 1283len 29 (too long)
# 1284len 28 (too long)
# 1285len 35 (too long)
# 1286len 12 (too long)
# 1287len 13 (too long)
# 1288len 36. success after 11597 iterations
# 1289len 27 (too long)
# 1290len 23 (too long)
# 1291len 18 (too long)
# 1292len 27 (too long)
# 1293len 32 (too long)
# 1294len 26 (too long)
# 1295len 18 (too long)
# 1296len 36. FAILED (reached max iterations 15000)
# 1297len 8 (too long)
# 1298len 33 (too long)
# 1299len 27 (too long)
# 1300len 46. FAILED (reached max iterations 15000)
# 1301len 11 (too long)
# 1302len 31 (too long)
# 1303len 21 (too long)
# 1304len 25 (too long)
# 1305len 51. FAILED (reached max iterations 15000)
# 1306len 18 (too long)
# 1307len 32 (too long)
# 1308len 29 (too long)
# 1309len 22 (too long)
# 1310len 29 (too long)
# 1311len 26 (too long)
# 1312len 50. FAILED (reached max iterations 15000)
# 1313len 32 (too long)
# 1314len 21 (too long)
# 1315len 10 (too long)
# 1316len 23 (too long)
# 1317len 11 (too long)
# 1318len 32 (too long)
# 1319len 15 (too long)
# 1320len 50. FAILED (reached max iterations 15000)
# 1321len 25 (too long)
# 1322len 42. FAILED (reached max iterations 15000)
# 1323len 27 (too long)
# 1324len 37. FAILED (reached max iterations 15000)
# 1325len 8 (too long)
# 1326len 29 (too long)
# 1327len 34 (too long)
# 1328len 26 (too long)
# 1329len 18 (too long)
# 1330len 20 (too long)
# 1331len 20 (too long)
# 1332len 10 (too long)
# 1333len 20 (too long)
# 1334len 12 (too long)
# 1335len 36. FAILED (reached max iterations 15000)
# 1336len 16 (too long)
# 1337len 12 (too long)
# 1338len 24 (too long)
# 1339len 42. FAILED (reached max iterations 15000)
# 1340len 23 (too long)
# 1341len 26 (too long)
# 1342len 28 (too long)
# 1343len 12 (too long)
# 1344len 10 (too long)
# 1345len 22 (too long)
# 1346len 34 (too long)
# 1347len 4 (too long)
# 1348len 14 (too long)
# 1349len 27 (too long)
# 1350len 12 (too long)
# 1351len 28 (too long)
# 1352len 15 (too long)
# 1353len 30 (too long)
# 1354len 27 (too long)
# 1355len 41. FAILED (reached max iterations 15000)
# 1356len 50. FAILED (reached max iterations 15000)
# 1357len 13 (too long)
# 1358len 39. success after 8343 iterations
# 1359len 25 (too long)
# 1360len 18 (too long)
# 1361len 19 (too long)
# 1362len 33 (too long)
# 1363len 15 (too long)
# 1364len 2 (too long)
# 1365len 38. FAILED (reached max iterations 15000)
# 1366len 23 (too long)
# 1367len 18 (too long)
# 1368len 21 (too long)
# 1369len 21 (too long)
# 1370len 21 (too long)
# 1371len 25 (too long)
# 1372len 32 (too long)
# 1373len 2 (too long)
# 1374len 22 (too long)
# 1375len 12 (too long)
# 1376len 30 (too long)
# 1377len 36. FAILED (reached max iterations 15000)
# 1378len 24 (too long)
# 1379len 25 (too long)
# 1380len 15 (too long)
# 1381len 19 (too long)
# 1382len 19 (too long)
# 1383len 15 (too long)
# 1384len 16 (too long)
# 1385len 17 (too long)
# 1386len 34 (too long)
# 1387len 22 (too long)
# 1388len 2 (too long)
# 1389len 19 (too long)
# 1390len 17 (too long)
# 1391len 34 (too long)
# 1392len 22 (too long)
# 1393len 22 (too long)
# 1394len 13 (too long)
# 1395len 27 (too long)
# 1396len 12 (too long)
# 1397len 2 (too long)
# 1398len 4 (too long)
# 1399len 13 (too long)
# 1400len 29 (too long)
# 1401len 34 (too long)
# 1402len 16 (too long)
# 1403len 18 (too long)
# 1404len 42. FAILED (reached max iterations 15000)
# 1405len 26 (too long)
# 1406len 3 (too long)
# 1407len 50. FAILED (reached max iterations 15000)
# 1408len 21 (too long)
# 1409len 23 (too long)
# 1410len 15 (too long)
# 1411len 22 (too long)
# 1412len 31 (too long)
# 1413len 53. FAILED (reached max iterations 15000)
# 1414len 21 (too long)
# 1415len 44. FAILED (reached max iterations 15000)
# 1416len 31 (too long)
# 1417len 19 (too long)
# 1418len 21 (too long)
# 1419len 11 (too long)
# 1420len 19 (too long)
# 1421len 45. FAILED (reached max iterations 15000)
# 1422len 38. success after 5196 iterations
# 1423len 10 (too long)
# 1424len 30 (too long)
# 1425len 37. FAILED (reached max iterations 15000)
# 1426len 18 (too long)
# 1427len 47. FAILED (reached max iterations 15000)
# 1428len 29 (too long)
# 1429len 36. FAILED (reached max iterations 15000)
# 1430len 15 (too long)
# 1431len 36. success after 8760 iterations
# 1432len 57. FAILED (reached max iterations 15000)
# 1433len 17 (too long)
# 1434len 12 (too long)
# 1435len 38. FAILED (reached max iterations 15000)
# 1436len 24 (too long)
# 1437len 28 (too long)
# 1438len 45. FAILED (reached max iterations 15000)
# 1439len 19 (too long)
# 1440len 22 (too long)
# 1441len 27 (too long)
# 1442len 60. FAILED (reached max iterations 15000)
# 1443len 15 (too long)
# 1444len 38. FAILED (reached max iterations 15000)
# 1445len 45. FAILED (reached max iterations 15000)
# 1446len 19 (too long)
# 1447len 16 (too long)
# 1448len 24 (too long)
# 1449len 20 (too long)
# 1450len 30 (too long)
# 1451len 41. FAILED (reached max iterations 15000)
# 1452len 16 (too long)
# 1453len 17 (too long)
# 1454len 37. success after 12203 iterations
# 1455len 16 (too long)
# 1456len 22 (too long)
# 1457len 39. FAILED (reached max iterations 15000)
# 1458len 33 (too long)
# 1459len 19 (too long)
# 1460len 17 (too long)
# 1461len 28 (too long)
# 1462len 25 (too long)
# 1463len 12 (too long)
# 1464len 27 (too long)
# 1465len 40. FAILED (reached max iterations 15000)
# 1466len 11 (too long)
# 1467len 14 (too long)
# 1468len 24 (too long)
# 1469len 8 (too long)
# 1470len 45. FAILED (reached max iterations 15000)
# 1471len 30 (too long)
# 1472len 15 (too long)
# 1473len 19 (too long)
# 1474len 32 (too long)
# 1475len 12 (too long)
# 1476len 23 (too long)
# 1477len 22 (too long)
# 1478len 17 (too long)
# 1479len 19 (too long)
# 1480len 11 (too long)
# 1481len 24 (too long)
# 1482len 11 (too long)
# 1483len 13 (too long)
# 1484len 15 (too long)
# 1485len 44. FAILED (reached max iterations 15000)
# 1486len 4 (too long)
# 1487len 29 (too long)
# 1488len 31 (too long)
# 1489len 12 (too long)
# 1490len 34 (too long)
# 1491len 32 (too long)
# 1492len 17 (too long)
# 1493len 9 (too long)
# 1494len 24 (too long)
# 1495len 21 (too long)
# 1496len 22 (too long)
# 1497len 11 (too long)
# 1498len 35 (too long)
# 1499len 17 (too long)
# 1500len 7 (too long)
# 1501len 20 (too long)
# 1502len 31 (too long)
# 1503len 21 (too long)
# 1504len 35 (too long)
# 1505len 17 (too long)
# 1506len 33 (too long)
# 1507len 26 (too long)
# 1508len 14 (too long)
# 1509len 11 (too long)
# 1510len 26 (too long)
# 1511len 24 (too long)
# 1512len 29 (too long)
# 1513len 21 (too long)
# 1514len 28 (too long)
# 1515len 39. FAILED (reached max iterations 15000)
# 1516len 14 (too long)
# 1517len 25 (too long)
# 1518len 26 (too long)
# 1519len 19 (too long)
# 1520len 26 (too long)
# 1521len 18 (too long)
# 1522len 24 (too long)
# 1523len 16 (too long)
# 1524len 15 (too long)
# 1525len 16 (too long)
# 1526len 15 (too long)
# 1527len 23 (too long)
# 1528len 17 (too long)
# 1529len 8 (too long)
# 1530len 27 (too long)
# 1531len 24 (too long)
# 1532len 18 (too long)
# 1533len 19 (too long)
# 1534len 21 (too long)
# 1535len 11 (too long)
# 1536len 9 (too long)
# 1537len 17 (too long)
# 1538len 19 (too long)
# 1539len 31 (too long)
# 1540len 16 (too long)
# 1541len 29 (too long)
# 1542len 25 (too long)
# 1543len 20 (too long)
# 1544len 8 (too long)
# 1545len 19 (too long)
# 1546len 17 (too long)
# 1547len 14 (too long)
# 1548len 7 (too long)
# 1549len 17 (too long)
# 1550len 8 (too long)
# 1551len 11 (too long)
# 1552len 29 (too long)
# 1553len 38. success after 6767 iterations
# 1554len 25 (too long)
# 1555len 21 (too long)
# 1556len 27 (too long)
# 1557len 15 (too long)
# 1558len 12 (too long)
# 1559len 26 (too long)
# 1560len 10 (too long)
# 1561len 30 (too long)
# 1562len 19 (too long)
# 1563len 6 (too long)
# 1564len 30 (too long)
# 1565len 27 (too long)
# 1566len 23 (too long)
# 1567len 15 (too long)
# 1568len 29 (too long)
# 1569len 35 (too long)
# 1570len 28 (too long)
# 1571len 19 (too long)
# 1572len 12 (too long)
# 1573len 24 (too long)
# 1574len 19 (too long)
# 1575len 12 (too long)
# 1576len 18 (too long)
# 1577len 21 (too long)
# 1578len 46. FAILED (reached max iterations 15000)
# 1579len 27 (too long)
# 1580len 6 (too long)
# 1581len 46. FAILED (reached max iterations 15000)
# 1582len 33 (too long)
# 1583len 17 (too long)
# 1584len 15 (too long)
# 1585len 13 (too long)
# 1586len 28 (too long)
# 1587len 18 (too long)
# 1588len 19 (too long)
# 1589len 32 (too long)
# 1590len 6 (too long)
# 1591len 11 (too long)
# 1592len 37. FAILED (reached max iterations 15000)
# 1593len 5 (too long)
# 1594len 40. success after 5483 iterations
# 1595len 31 (too long)
# 1596len 16 (too long)
# 1597len 37. success after 9313 iterations
# 1598len 28 (too long)
# 1599len 28 (too long)
# 1600len 30 (too long)
# 1601len 27 (too long)
# 1602len 40. FAILED (reached max iterations 15000)
# 1603len 16 (too long)
# 1604len 22 (too long)
# 1605len 9 (too long)
# 1606len 22 (too long)
# 1607len 22 (too long)
# 1608len 15 (too long)
# 1609len 14 (too long)
# 1610len 14 (too long)
# 1611len 22 (too long)
# 1612len 14 (too long)
# 1613len 18 (too long)
# 1614len 10 (too long)
# 1615len 18 (too long)
# 1616len 24 (too long)
# 1617len 31 (too long)
# 1618len 29 (too long)
# 1619len 24 (too long)
# 1620len 17 (too long)
# 1621len 20 (too long)
# 1622len 21 (too long)
# 1623len 31 (too long)
# 1624len 26 (too long)
# 1625len 23 (too long)
# 1626len 32 (too long)
# 1627len 27 (too long)
# 1628len 19 (too long)
# 1629len 18 (too long)
# 1630len 30 (too long)
# 1631len 29 (too long)
# 1632len 32 (too long)
# 1633len 46. FAILED (reached max iterations 15000)
# 1634len 30 (too long)
# 1635len 20 (too long)
# 1636len 15 (too long)
# 1637len 36. success after 1302 iterations
# 1638len 11 (too long)
# 1639len 20 (too long)
# 1640len 24 (too long)
# 1641len 21 (too long)
# 1642len 25 (too long)
# 1643len 22 (too long)
# 1644len 14 (too long)
# 1645len 17 (too long)
# 1646len 36. FAILED (reached max iterations 15000)
# 1647len 29 (too long)
# 1648len 27 (too long)
# 1649len 40. FAILED (reached max iterations 15000)
# 1650len 18 (too long)
# 1651len 24 (too long)
# 1652len 17 (too long)
# 1653len 32 (too long)
# 1654len 17 (too long)
# 1655len 40. FAILED (reached max iterations 15000)
# 1656len 16 (too long)
# 1657len 40. FAILED (reached max iterations 15000)
# 1658len 32 (too long)
# 1659len 25 (too long)
# 1660len 29 (too long)
# 1661len 27 (too long)
# 1662len 28 (too long)
# 1663len 18 (too long)
# 1664len 48. FAILED (reached max iterations 15000)
# 1665len 31 (too long)
# 1666len 28 (too long)
# 1667len 26 (too long)
# 1668len 33 (too long)
# 1669len 24 (too long)
# 1670len 20 (too long)
# 1671len 44. FAILED (reached max iterations 15000)
# 1672len 15 (too long)
# 1673len 23 (too long)
# 1674len 18 (too long)
# 1675len 17 (too long)
# 1676len 26 (too long)
# 1677len 25 (too long)
# 1678len 33 (too long)
# 1679len 18 (too long)
# 1680len 32 (too long)
# 1681len 16 (too long)
# 1682len 25 (too long)
# 1683len 17 (too long)
# 1684len 39. success after 7548 iterations
# 1685len 31 (too long)
# 1686len 18 (too long)
# 1687len 23 (too long)
# 1688len 23 (too long)
# 1689len 24 (too long)
# 1690len 32 (too long)
# 1691len 18 (too long)
# 1692len 19 (too long)
# 1693len 22 (too long)
# 1694len 24 (too long)
# 1695len 16 (too long)
# 1696len 12 (too long)
# 1697len 25 (too long)
# 1698len 24 (too long)
# 1699len 49. FAILED (reached max iterations 15000)

# %%
print(np.nanmean(scores), f", n={countobs-failurecount} (Failure rate: {failurecount}/{countobs})")
# Out:
# 0.3548713256831176 , n=41 (Failure rate: 192/233)

# %% [markdown]
# with $14 \leq |s| \leq35$, and  1000 iterations for rejection sampling:
# > mean acc = 0.387, n=828   (Failure rate: 343/1171)
#
#
# Now for 15000 iterations:
#
# - with $14 \leq |s| \leq35$, mean acc = `0.372` , n=1116 (Failure rate: 55/1171)
#
# - and with $2 < |s| \leq13$, mean acc = `0.525` , n=280 (Failure rate: 0/280)
#
# - and with $35 < |s|$, mean acc = `0.355` , n=41 (Failure rate: 192/233)
#
# - so overall mean acc = $(0.525 * 280+0.372 * 1116+0.355 * 41)/(280 + 1116 + 41) =$ `0.401`, with a failure rate of $(55 + 192) / ( 280 + 1116 + 41 ) = 247/1684 =$ `0.172`

# %% [markdown]
# For comparison, we can also get the score of the CPMI trees:

# %%
gold_edges = [literal_eval(EDGES_DF.at[i, "gold_edges"]) for i,row in EDGES_DF.iterrows()]
cpmi_edges = [literal_eval(EDGES_DF.at[i, "projective.edges.sum"]) for i,row in EDGES_DF.iterrows()]

cpmi_scores = [score_observation(cpmi_edges[i],OBSERVATIONS[i],convert_from_0index=True) 
          for i,_ in enumerate(OBSERVATIONS)]
np.nanmean(cpmi_scores)
# Out:
# 0.48217553684114794
